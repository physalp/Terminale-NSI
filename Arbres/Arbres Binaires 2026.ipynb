# %% [markdown]
# <h1><center><span style="color:#369;padding: 10px 30px 10px 30px;border: 3px solid #369;border-radius:7px;">implémentation d'une arbre binaire </span></center></h1>
#
# Un arbre binaire est un arbre de degré 2 (dont les noeuds sont de degré 2 au plus).
# Vocabulaire :
# Les enfants d’un noeud sont lus de gauche à droite et sont appelés: ﬁls gauche et ﬁls droit.
#
# Étiquette :
# Un arbre dont tous les noeuds sont nommés est dit étiqueté.L’étiquette (ou nom du sommet) représente la "valeur" du noeud ou bien l’information associée au noeud.
#
#
# Racine, noeud, branche, feuille :
# Un arbre est un ensemble organisé de noeuds dans lequel chaque noeud a un
# père, sauf un noeud que l’on appelle la racine.
# Si le noeud n’a pas de ﬁls, on dit que c’est une feuille.
# Les noeuds sont reliés par des branches.

# %% [markdown]
# ##  <span style="color:#369"> I. Implémenter les arbres:</span>
#
#
#     Les arbres binaires forment une structure de données qui peut se déﬁnir de façon récursive.
# Un arbre binaire est :
# • Soit vide.
# • Soit composé d’une racine portant une étiquette (clé) et d’une paire d’arbres binaires,
# appelés sous-arbres gauche et droit.

# %%
class Noeud():
    """Représente un noeud dans un arbre binaire
    - Propriétés :
        * valeur : valeur du noeud
        * gauche : noeud gauche ou None
        * droit  : noeud droit ou None
    - Méthodes   :
        * est_feuille() 
        * __repr__() : affichage d'un noeud"""
        
    def __init__(self,valeur):
        """ Constructeur """
        self.valeur = valeur
        self.gauche = None
        self.droit = None
    
    def ajouter_gauche(self,valeur):
        """ ajoute un fils gauche """
        self.gauche=Noeud(valeur)
    
    def ajouter_droit(self,valeur):
        """ ajoute un fils droit """
        self.droit=Noeud(valeur)
    
    def __str__(self):
        """
        Méthode de représentation
        """
        return f"[{self.valeur}, {self.gauche}, {self.droit}]"
    
    def afficher_arbre(self, indent="", last=True):
        """ Affichage ASCII de l'arbre """
        print(indent, "`- " if last else "|- ", self.valeur, sep="")

        indent += "   " if last else "|  "

        # fils gauche
        if self.gauche:
            self.gauche.afficher_arbre(indent, False)

        # fils droit
        if self.droit:
            self.droit.afficher_arbre(indent, True)

# %%
arbre=Noeud("I")
arbre.ajouter_gauche("I")
arbre.ajouter_droit("E")
arbre.gauche.ajouter_gauche("J")
arbre.gauche.ajouter_droit("I")
arbre.droit.ajouter_gauche("O")
arbre.droit.ajouter_droit("E")
print(arbre)
arbre.afficher_arbre()
# Out:
# [I, [I, [J, None, None], [I, None, None]], [E, [O, None, None], [E, None, None]]]

# %% [markdown]
# !!! info Un noeud est une feuille si il n'a pas de fils
#
# Q1. Ajouter la méthode est feuile qui renvoie True si le Noeud est une feuille:
#
# !!!

# %% [markdown]
# !!! info Hauteur d’un noeud :
#
# la hauteur(ou profondeur ou niveau ) d’un noeud X est égale au nombre d’arêtes qu’il
# faut parcourir à partir de la racine pour aller jusqu’au noeud X.
#
# Q2. Ajouter la méthode hauteur qui renvoie la hauteur du Noeud
#
# !!!

# %% [markdown]
# !!! info La hauteur (ou profondeur) d’un arbre est égale à la profondeur du noeud le plus profond.
#
# Q3. Ajouter la méthode hauteur_arbre(self) qui renvoie la hauteur de l'arbre.
#
# !!!

# %% [markdown]
# !!! info La taille d’un arbre est égale au nombre de noeuds de l’arbre.
#
# Q4. Ajouter la méthode taille qui renvoie la taille de l'arbre
#
# !!!

# %% [markdown]
# !!! info Le degré d’un noeud est égal au nombre de ses descendants (enfants).
#
#
# Q5. Ajouter la méthode degré qui renvoie le degré d'un Noeud.
#
# !!!

# %% [markdown]
# !!! info Le degré d’un arbre est égal au plus grand des degrés de ses noeuds
#
# Q6. Implémenter la méthode degré(self) qui renvoie le degré d’un Nœud.
#
# !!!

# %% [markdown]
# !!! info le minimum d'un arbre
#
# Q7. Implémenter la méthode minimum(self) qui renvoie le minimum
#
# !!!

# %% [markdown]
# !!! question
#
# Q8. Ajouter la méthode  ``recherche_iter(self,valeur)`` pour qu'elle renvoie True si la valeur est dans l'ABR et False sinon, en effectuant une recherche itérative.
#
# !!!

# %% [markdown]
# !!! question
#
# Q9. Compléter  le code de la méthode ``recherche_rec(self,valeur)`` pour qu'elle renvoie True si la valeur est dans l'ABR et False sinon, en effectuant une recherche récursive.
#
# !!!
